# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = pd.read_csv('/content/customer.csv')

# %%
df.sample(10)
# Out:
#     age  gender   review education purchased
# 44   77  Female  Average        UG        No
# 7    60  Female     Poor    School       Yes
# 30   73    Male  Average        UG        No
# 6    18    Male     Good    School        No
# 35   74    Male     Poor    School       Yes
# 16   59    Male     Poor        UG       Yes
# 3    72  Female     Good        PG        No
# 40   39    Male     Good    School        No
# 24   16  Female  Average        PG       Yes
# 26   53  Female     Poor        PG        No

# %%
df.shape
# Out:
# (50, 5)

# %%
sns.boxplot(x=df['gender'],y=df['age'],hue=df['education'])
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sns.scatterplot(x = df['age'],y = df['education'],hue = df['gender'])
# Out:
# <Axes: xlabel='age', ylabel='education'>

# %%
sns.barplot(x = df['gender'],y = df['age'],hue = df['education'])
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sns.barplot(x = tips['time'],y = tips['tip'],hue = tips['smoker'])
# Out:
# <Axes: xlabel='time', ylabel='tip'>
