# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features = 5,n_redundant = 0,n_informative = 5,n_clusters_per_class = 1)

# %%
df = pd.DataFrame(X,columns = ['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.423934  1.388478  0.554345  0.545602 -0.852041       0
# 1 -2.700843 -2.061969 -0.675335  1.842298 -3.259048       0
# 2  1.844591 -3.163954 -1.187583  4.543162 -1.239429       0
# 3  1.273592  0.255388 -1.276289  0.472062  1.085377       1
# 4  0.096319 -0.729395 -1.516300  0.724005  1.092047       1

# %%
bag = BaggingClassifier(max_features = 2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features = 2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
# Out:
# [Text(0.5454545454545454, 0.9375, 'x[3] <= 2.179\ngini = 0.499\nsamples = 61\nvalue = [52, 48]'),
#  Text(0.36363636363636365, 0.8125, 'x[0] <= -2.536\ngini = 0.491\nsamples = 50\nvalue = [36.0, 47.0]'),
#  Text(0.45454545454545453, 0.875, 'True  '),
#  Text(0.2727272727272727, 0.6875, 'gini = 0.0\nsamples = 9\nvalue = [0, 11]'),
#  Text(0.45454545454545453, 0.6875, 'x[1] <= -1.583\ngini = 0.5\nsamples = 41\nvalue = [36, 36]'),
#  Text(0.18181818181818182, 0.5625, 'x[3] <= 1.425\ngini = 0.291\nsamples = 10\nvalue = [3, 14]'),
#  Text(0.09090909090909091, 0.4375, 'gini = 0.0\nsamples = 7\nvalue = [0, 12]'),
#  Text(0.2727272727272727, 0.4375, 'x[0] <= 0.566\ngini = 0.48\nsamples = 3\nvalue = [3, 2]'),
#  Text(0.18181818181818182, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.36363636363636365, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.7272727272727273, 0.5625, 'x[1] <= 0.74\ngini = 0.48\nsamples = 31\nvalue = [33, 22]'),
#  Text(0.6363636363636364, 0.4375, 'x[1] <= -1.439\ngini = 0.498\nsamples = 26\nvalue = [25, 22]'),
#  Text(0.5454545454545454, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(0.7272727272727273, 0.3125, 'x[4] <= 0.646\ngini = 0.495\nsamples = 22\nvalue = [18, 22]'),
#  Text(0.6363636363636364, 0.1875, 'gini = 0.0\nsamples = 10\nvalue = [16, 0]'),
#  Text(0.8181818181818182, 0.1875, 'x[3] <= 0.207\ngini = 0.153\nsamples = 12\nvalue = [2, 22]'),
#  Text(0.7272727272727273, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.9090909090909091, 0.0625, 'gini = 0.0\nsamples = 11\nvalue = [0, 22]'),
#  Text(0.8181818181818182, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [8, 0]'),
#  Text(0.7272727272727273, 0.8125, 'x[0] <= -3.006\ngini = 0.111\nsamples = 11\nvalue = [16, 1]'),
#  Text(0.6363636363636364, 0.875, '  False'),
#  Text(0.6363636363636364, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8181818181818182, 0.6875, 'gini = 0.0\nsamples = 10\nvalue = [16, 0]')]
